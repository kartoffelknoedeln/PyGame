# %% [markdown]
# ## --- Importing data ---

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  Poison   45      49       49       65       65
# 1      2     Ivysaur    Grass  Poison   60      62       63       80       80
# 2      3    Venusaur    Grass  Poison   80      82       83      100      100
# 3      4  Charmander     Fire     NaN   39      52       43       60       50
# 4      5  Charmeleon     Fire     NaN   58      64       58       80       65
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 246  247     Pupitar     Rock  Ground   70      84       70       65       70
# 247  248   Tyranitar     Rock    Dark  100     134      110       95      100
# 248  249       Lugia  Psychic  Flying  106      90      130       90      154
# 249  250       Ho-oh     Fire  Flying  106     130       90      110      154
# 250  251      Celebi  Psychic   Grass  100     100      100      100      100
#
# ...

# %% [markdown]
# ## --- Listing out the columns ---

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## --- Listing out row values by columns ---

# %%
df[['#', 'Name', 'Type 1', 'Type 2']]
# Out:
#        #        Name   Type 1  Type 2
# 0      1   Bulbasaur    Grass  Poison
# 1      2     Ivysaur    Grass  Poison
# 2      3    Venusaur    Grass  Poison
# 3      4  Charmander     Fire     NaN
# 4      5  Charmeleon     Fire     NaN
# ..   ...         ...      ...     ...
# 246  247     Pupitar     Rock  Ground
# 247  248   Tyranitar     Rock    Dark
# 248  249       Lugia  Psychic  Flying
# 249  250       Ho-oh     Fire  Flying
# 250  251      Celebi  Psychic   Grass
#
# [251 rows x 4 columns]

# %% [markdown]
# ## --- Data selection (numerical) ---

# %%
df.iloc[0:151]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  Poison   45      49       49       65       65
# 1      2     Ivysaur    Grass  Poison   60      62       63       80       80
# 2      3    Venusaur    Grass  Poison   80      82       83      100      100
# 3      4  Charmander     Fire     NaN   39      52       43       60       50
# 4      5  Charmeleon     Fire     NaN   58      64       58       80       65
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon     NaN   41      64       45       50       50
# 147  148   Dragonair   Dragon     NaN   61      84       65       70       70
# 148  149   Dragonite   Dragon  Flying   91     134       95      100      100
# 149  150      Mewtwo  Psychic     NaN  106     110       90      154       90
# 150  151         Mew  Psychic     NaN  100     100      100      100      100
#
# ...

# %%
df.iloc[152:251]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 152  153     Bayleef    Grass     NaN   60      62       80       63       80
# 153  154    Meganium    Grass     NaN   80      82      100       83      100
# 154  155   Cyndaquil     Fire     NaN   39      52       43       60       50
# 155  156     Quilava     Fire     NaN   58      64       58       80       65
# 156  157  Typhlosion     Fire     NaN   78      84       78      109       85
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 246  247     Pupitar     Rock  Ground   70      84       70       65       70
# 247  248   Tyranitar     Rock    Dark  100     134      110       95      100
# 248  249       Lugia  Psychic  Flying  106      90      130       90      154
# 249  250       Ho-oh     Fire  Flying  106     130       90      110      154
# 250  251      Celebi  Psychic   Grass  100     100      100      100      100
#
# ...

# %%
df.iloc[149,1]
# Out:
# 'Mewtwo'

# %% [markdown]
# ## --- Data selection (string) ---

# %%
df.loc[(df['Type 1'] == 'Psychic') & (df['Generation'] == 1)]
# Out:
#        #      Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 62    63      Abra  Psychic    NaN   25      20       15      105       55
# 63    64   Kadabra  Psychic    NaN   40      35       30      120       70
# 64    65  Alakazam  Psychic    NaN   55      50       45      135       95
# 95    96   Drowzee  Psychic    NaN   60      48       45       43       90
# 96    97     Hypno  Psychic    NaN   85      73       70       73      115
# 121  122  Mr. Mime  Psychic    NaN   40      45       65      100      120
# 149  150    Mewtwo  Psychic    NaN  106     110       90      154       90
# 150  151       Mew  Psychic    NaN  100     100      100      100      100
#
#      Speed  Generation  Legendary
# 62      90           1      False
# 63     105           1      False
# 64     120           1      False
# 95      42           1      False
# 96      67           1      False
# 121     90           1      False
# 149    130           1       True
# ...

# %% [markdown]
# ## --- Row iteration ---

# %%
for index, row in df.iterrows():
    print(row['#'], row['Name'])
# Out:
# 1 Bulbasaur
# 2 Ivysaur
# 3 Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 Squirtle
# 8 Wartortle
# 9 Blastoise
# 10 Caterpie
# 11 Metapod
# 12 Butterfree
# 13 Weedle
# 14 Kakuna
# 15 Beedrill
# 16 Pidgey
# 17 Pidgeotto
# 18 Pidgeot
# 19 Rattata
# 20 Raticate
# 21 Spearow
# 22 Fearow
# 23 Ekans
# 24 Arbok
# 25 Pikachu
# 26 Raichu
# 27 Sandshrew
# 28 Sandslash
# 29 Nidoran (Female)
# 30 Nidorina
# 31 Nidoqueen
# 32 Nidoran (Male)
# 33 Nidorino
# 34 Nidoking
# 35 Clefairy
# 36 Clefable
# 37 Vulpix
# 38 Ninetales
# 39 Jigglypuff
# 40 Wigglytuff
# 41 Zubat
# 42 Golbat
# 43 Oddish
# 44 Gloom
# 45 Vileplume
# 46 Paras
# 47 Parasect
# 48 Venonat
# 49 Venomoth
# 50 Diglett
# 51 Dugtrio
# 52 Meowth
# 53 Persian
# 54 Psyduck
# 55 Golduck
# 56 Mankey
# 57 Primeape
# 58 Growlithe
# 59 Arcanine
# 60 Poliwag
# 61 Poliwhirl
# 62 Poliwrath
# 63 Abra
# 64 Kadabra
# 65 Alakazam
# 66 Machop
# 67 Machoke
# 68 Machamp
# 69 Bellsprout
# 70 Weepinbell
# 71 Victreebel
# 72 Tentacool
# ...

# %% [markdown]
# ## --- Describe ---

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   126.000000   66.749004   70.840637   68.729084   66.007968   68.458167
# std     72.601653   29.797261   27.361844   30.399841   27.323688   27.452236
# min      1.000000   10.000000    5.000000    5.000000   10.000000   20.000000
# 25%     63.500000   49.000000   50.000000   49.500000   45.000000   50.000000
# 50%    126.000000   65.000000   70.000000   65.000000   65.000000   65.000000
# 75%    188.500000   80.000000   90.000000   85.000000   85.000000   85.000000
# max    251.000000  255.000000  134.000000  230.000000  154.000000  230.000000
#
#             Speed  Generation
# count  251.000000  251.000000
# mean    65.936255    1.398406
# std     27.143101    0.490548
# min      5.000000    1.000000
# 25%     45.000000    1.000000
# 50%     65.000000    1.000000
# 75%     85.000000    2.000000
# ...

# %% [markdown]
# ## --- Sorting values ---

# %%
df.sort_values(['Sp. Atk', 'HP'], ascending=False)
# Out:
#        #       Name   Type 1   Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 149  150     Mewtwo  Psychic      NaN  106     110       90      154       90
# 64    65   Alakazam  Psychic      NaN   55      50       45      135       95
# 195  196     Espeon  Psychic      NaN   65      65       60      130       95
# 93    94     Gengar    Ghost   Poison   60      65       60      130       75
# 102  103  Exeggutor    Grass  Psychic   95      95       85      125       65
# ..   ...        ...      ...      ...  ...     ...      ...      ...      ...
# 26    27  Sandshrew   Ground      NaN   50      75       85       20       30
# 9     10   Caterpie      Bug      NaN   45      30       35       20       20
# 12    13     Weedle      Bug   Poison   40      35       30       20       20
# 128  129   Magikarp    Water      NaN   20      10       55       15       20
# 212  213    Shuckle      Bug     Rock   20      10      230       10      230
#
# ...

# %% [markdown]
# ## --- Adding columns ---

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  Poison   45      49       49       65       65
# 1      2     Ivysaur    Grass  Poison   60      62       63       80       80
# 2      3    Venusaur    Grass  Poison   80      82       83      100      100
# 3      4  Charmander     Fire     NaN   39      52       43       60       50
# 4      5  Charmeleon     Fire     NaN   58      64       58       80       65
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 246  247     Pupitar     Rock  Ground   70      84       70       65       70
# 247  248   Tyranitar     Rock    Dark  100     134      110       95      100
# 248  249       Lugia  Psychic  Flying  106      90      130       90      154
# 249  250       Ho-oh     Fire  Flying  106     130       90      110      154
# 250  251      Celebi  Psychic   Grass  100     100      100      100      100
#
# ...

# %%
# This is the same as above. The syntax [:,4:10] means you're adding all the columbs between the 4th to the 9th column.
# The sum() at the end determines if you're adding vertically or horizonally:
# 0 is vertically and 1 is horizontally.

df['Total'] = df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  Poison   45      49       49       65       65
# 1      2     Ivysaur    Grass  Poison   60      62       63       80       80
# 2      3    Venusaur    Grass  Poison   80      82       83      100      100
# 3      4  Charmander     Fire     NaN   39      52       43       60       50
# 4      5  Charmeleon     Fire     NaN   58      64       58       80       65
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 246  247     Pupitar     Rock  Ground   70      84       70       65       70
# 247  248   Tyranitar     Rock    Dark  100     134      110       95      100
# 248  249       Lugia  Psychic  Flying  106      90      130       90      154
# 249  250       Ho-oh     Fire  Flying  106     130       90      110      154
# 250  251      Celebi  Psychic   Grass  100     100      100      100      100
#
# ...

# %% [markdown]
# ## --- Column rearranging ---

# %%
cols = list(df.columns.values)
cols_rearrange_df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
cols_rearrange_df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 246  247     Pupitar     Rock  Ground    410   70      84       70       65
# 247  248   Tyranitar     Rock    Dark    600  100     134      110       95
# 248  249       Lugia  Psychic  Flying    680  106      90      130       90
# 249  250       Ho-oh     Fire  Flying    680  106     130       90      110
# 250  251      Celebi  Psychic   Grass    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
index_reset = df.loc[(df['Type 1'] == 'Psychic') | (df['Type 2'] == 'Flying') & (df['Generation'] == 2)]
index_reset.reset_index(drop=True,inplace=True)
index_reset
# Out:
#       #       Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    63       Abra  Psychic     NaN   25      20       15      105       55
# 1    64    Kadabra  Psychic     NaN   40      35       30      120       70
# 2    65   Alakazam  Psychic     NaN   55      50       45      135       95
# 3    96    Drowzee  Psychic     NaN   60      48       45       43       90
# 4    97      Hypno  Psychic     NaN   85      73       70       73      115
# 5   122   Mr. Mime  Psychic     NaN   40      45       65      100      120
# 6   150     Mewtwo  Psychic     NaN  106     110       90      154       90
# 7   151        Mew  Psychic     NaN  100     100      100      100      100
# 8   163   Hoothoot   Normal  Flying   60      30       30       36       56
# 9   164    Noctowl   Normal  Flying  100      50       50       76       96
# 10  165     Ledyba      Bug  Flying   40      20       30       40       80
# ...

# %% [markdown]
# ## --- String search ---

# %%
df.loc[df['Name'].str.contains('chu')]
# Out:
#        #      Name    Type 1   Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 24    25   Pikachu  Electric      NaN  35      55       40       50       50
# 25    26    Raichu  Electric      NaN  60      90       55       90       80
# 171  172     Pichu  Electric      NaN  20      40       15       35       35
# 237  238  Smoochum       Ice  Psychic  45      30       15       85       65
#
#      Speed  Generation  Legendary  Total
# 24      90           1      False    320
# 25     110           1      False    485
# 171     60           2      False    205
# 237     65           2      False    305

# %%
df.loc[~df['Name'].str.contains('a')]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 6      7    Squirtle    Water     NaN   44      48       65       50       64
# 11    12  Butterfree      Bug  Flying   60      45       50       90       80
# 12    13      Weedle      Bug  Poison   40      35       30       20       20
# 14    15    Beedrill      Bug  Poison   65      90       40       45       80
# 15    16      Pidgey   Normal  Flying   40      45       40       35       35
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 241  242     Blissey   Normal     NaN  255      10       10       75      135
# 243  244       Entei     Fire     NaN  115     115       85       90       75
# 244  245     Suicune    Water     NaN  100      75      115       90      115
# 249  250       Ho-oh     Fire  Flying  106     130       90      110      154
# 250  251      Celebi  Psychic   Grass  100     100      100      100      100
#
# ...

# %% [markdown]
# ## --- Regex ---

# %%
# The flag 're.I' is ignore, which allows us to look for all names regardless of its cases.

import re

df.loc[df['Type 1'].str.contains('dark|steel', flags=re.I, regex=True)]
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 196  197   Umbreon   Dark     NaN  95      65      110       60      130
# 197  198   Murkrow   Dark  Flying  60      85       42       85       42
# 207  208   Steelix  Steel  Ground  75      85      200       55       65
# 214  215   Sneasel   Dark     Ice  55      95       55       35       75
# 226  227  Skarmory  Steel  Flying  65      80      140       40       70
# 227  228  Houndour   Dark    Fire  45      60       30       80       50
# 228  229  Houndoom   Dark    Fire  75      90       50      110       80
#
#      Speed  Generation  Legendary  Total
# 196     65           2      False    525
# 197     91           2      False    405
# 207     30           2      False    510
# 214    115           2      False    430
# 226     70           2      False    465
# 227     65           2      False    330
# 228     95           2      False    500

# %%
import re

df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #       Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 15    16     Pidgey    Normal  Flying   40      45       40       35       35
# 16    17  Pidgeotto    Normal  Flying   63      60       55       50       50
# 17    18    Pidgeot    Normal  Flying   83      80       75       70       70
# 24    25    Pikachu  Electric     NaN   35      55       40       50       50
# 126  127     Pinsir       Bug     NaN   65     125      100       55       70
# 171  172      Pichu  Electric     NaN   20      40       15       35       35
# 203  204     Pineco       Bug     NaN   50      65       90       35       35
# 220  221  Piloswine       Ice  Ground  100     100       80       60       60
#
#      Speed  Generation  Legendary  Total
# 15      56           1      False    251
# 16      71           1      False    349
# 17     101           1      False    479
# 24      90           1      False    320
# 126     85           1      False    500
# ...

# %% [markdown]
# ## --- Value changes ---

# %%
type_changer = df.loc[df['Type 1'] == 'Steel', 'Type 1'] = 'Metal'
df.tail(50)
# Out:
#        #        Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 201  202   Wobbuffet   Psychic       NaN  190      33       58       33
# 202  203   Girafarig    Normal   Psychic   70      80       65       90
# 203  204      Pineco       Bug       NaN   50      65       90       35
# 204  205  Forretress       Bug     Steel   75      90      140       60
# 205  206   Dunsparce    Normal       NaN  100      70       70       65
# 206  207      Gligar    Ground    Flying   65      75      105       35
# 207  208     Steelix     Metal    Ground   75      85      200       55
# 208  209    Snubbull    Normal       NaN   60      80       50       40
# 209  210    Granbull    Normal       NaN   90     120       75       60
# 210  211    Qwilfish     Water    Poison   65      95       75       55
# 211  212      Scizor       Bug     Steel   70     130      100       55
# 212  213     Shuckle       Bug      Rock   20      10      230       10
# ...

# %%
type_changer = df.loc[df['Type 1'] == 'Metal', 'Type 1'] = 'Steel'
df.tail(50)
# Out:
#        #        Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 201  202   Wobbuffet   Psychic       NaN  190      33       58       33
# 202  203   Girafarig    Normal   Psychic   70      80       65       90
# 203  204      Pineco       Bug       NaN   50      65       90       35
# 204  205  Forretress       Bug     Steel   75      90      140       60
# 205  206   Dunsparce    Normal       NaN  100      70       70       65
# 206  207      Gligar    Ground    Flying   65      75      105       35
# 207  208     Steelix     Steel    Ground   75      85      200       55
# 208  209    Snubbull    Normal       NaN   60      80       50       40
# 209  210    Granbull    Normal       NaN   90     120       75       60
# 210  211    Qwilfish     Water    Poison   65      95       75       55
# 211  212      Scizor       Bug     Steel   70     130      100       55
# 212  213     Shuckle       Bug      Rock   20      10      230       10
# ...

# %% [markdown]
# ## --- Statistics ---

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
#                    #         HP     Attack     Defense     Sp. Atk    Sp. Def  \
# Type 1
# Normal    128.022727  79.409091  64.477273   54.818182   55.113636  63.386364
# Psychic   150.800000  75.000000  64.400000   64.733333   94.666667  87.000000
# Steel     217.500000  70.000000  82.500000  170.000000   47.500000  67.500000
# Water     129.260870  69.173913  69.413043   75.543478   66.173913  69.891304
# Dark      213.400000  66.000000  79.000000   57.400000   74.000000  75.400000
# Poison     58.933333  65.866667  75.466667   67.866667   58.000000  62.866667
# Ice       195.333333  65.833333  61.666667   52.500000   75.000000  70.000000
# Fire      120.450000  64.850000  80.850000   65.100000   84.200000  76.200000
# Ground    114.363636  64.545455  82.727273   88.636364   40.909091  51.818182
# Dragon    148.000000  64.333333  94.000000   68.333333   73.333333  73.333333
# Grass     107.380952  62.380952  64.809524   67.619048   76.666667  68.809524
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#            #  Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       22    22      18  22      22       22       22       22     22
# Dark       5     5       4   5       5        5        5        5      5
# Dragon     3     3       1   3       3        3        3        3      3
# Electric  15    15       3  15      15       15       15       15     15
# Fighting   9     9       0   9       9        9        9        9      9
# Fire      20    20       4  20      20       20       20       20     20
# Ghost      4     4       3   4       4        4        4        4      4
# Grass     21    21      14  21      21       21       21       21     21
# Ground    11    11       3  11      11       11       11       11     11
# Ice        6     6       6   6       6        6        6        6      6
# Normal    44    44      12  44      44       44       44       44     44
# Poison    15    15       5  15      15       15       15       15     15
# ...

# %%
df.groupby(['Type 1', 'Type 2']).count()['#']
# Out:
# Type 1    Type 2
# Bug       Fighting     1
#           Flying       5
#           Grass        2
#           Poison       7
#           Rock         1
#           Steel        2
# Dark      Fire         2
#           Flying       1
#           Ice          1
# Dragon    Flying       1
# Electric  Flying       1
#           Steel        2
# Fire      Flying       3
#           Rock         1
# Ghost     Poison       3
# Grass     Flying       3
#           Poison       9
#           Psychic      2
# Ground    Flying       1
#           Rock         2
# Ice       Flying       2
#           Ground       2
#           Psychic      2
# Normal    Flying      11
#           Psychic      1
# Poison    Flying       3
#           Ground       2
# Psychic   Flying       3
#           Grass        1
# Rock      Dark         1
#           Flying       1
#           Ground       6
#           Water        4
# Steel     Flying       1
#           Ground       1
# Water     Dragon       1
# ...

# %% [markdown]
# ## --- Special thanks ---
# https://www.youtube.com/watch?v=vmEHCJofslg
